# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df = pd.read_csv("adult_eda.csv")

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
# Your Code is Here
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qFn8RZs/US-Citicens1.png)

# %%
# Your Code is Here

df.shape
# Out:
# (32561, 15)

# %% [raw]
# Desired Output:
#
# (32561, 15)

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# Check if the Dataset have any Duplicate

# Your Code is Here
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %% [raw]
# Desired Output:
#
# False    32537
# True        24
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (32537, 15)

# %%
# Drop Duplicates

# Your Code is Here

df.drop_duplicates(inplace=True)

# %%
# Check the shape of the Dataset

# Your Code is Here

df.shape
# Out:
# (32537, 15)

# %% [raw]
# Desired Output:
#
# (32537, 15)

# %%
# Your Code is Here

df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/HnG6Xdn/US-Citicens2.png)

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32537 rows x 15 columns]

# %% [markdown]
# **Rename the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**, **respectively and permanently.**

# %%
# Your Code is Here
df.rename(columns={"education-num" :"education_num", "marital-status":"marital_status",
                   "capital-loss":"capital_loss", "capital-gain" :"capital_gain", "hours-per-week":"hours_per_week",
                   "native-country":"native_country"}, inplace=True)

# %%
# Check the sum of Missing Values per column

# Your Code is Here
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %% [raw]
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# gender               0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values

# Your Code is Here

df.isnull().sum() / df.shape[0] * 100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [raw]
# Desired Output:
#
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# gender            0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %%
df.nunique().index
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
# Your Code is Here
df.nunique().index
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %% [raw]
# Desired Output:
#
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32537 rows x 15 columns]

# %%
df.select_dtypes(include=object).nunique()
# Out:
# workclass          9
# education         16
# marital_status     7
# occupation        15
# relationship       5
# race               5
# sex                2
# native_country    42
# salary             2
# dtype: int64

# %%
a = df.select_dtypes(include=object).nunique()

# %%
b = pd.DataFrame(a)

# %%
b
# Out:
#                  0
# workclass        9
# education       16
# marital_status   7
# occupation      15
# relationship     5
# race             5
# sex              2
# native_country  42
# salary           2

# %%
 df.select_dtypes(include=object).count()
# Out:
# workclass         32537
# education         32537
# marital_status    32537
# occupation        32537
# relationship      27473
# race              32537
# sex               32537
# native_country    32537
# salary            32537
# dtype: int64

# %%
 df.select_dtypes(include=object).nunique()
# Out:
# workclass          9
# education         16
# marital_status     7
# occupation        15
# relationship       5
# race               5
# sex                2
# native_country    42
# salary             2
# dtype: int64

# %%
 df.select_dtypes(include=object)
# Out:
#               workclass   education      marital_status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex native_country salary
# 0      Not-in-family  White    Male  United-States  <=50K
# 1            Husband  White    Male  United-States  <=50K
# 2      Not-in-family  White    Male  United-States  <=50K
# 3            Husband  Black    Male  United-States  <=50K
# 4               Wife  Black  Female           Cuba  <=50K
# ...              ...    ...     ...            ...    ...
# 32556           Wife  White  Female  United-States  <=50K
# 32557        Husband  White    Male  United-States   >50K
# 32558      Unmarried  White  Female  United-States  <=50K
# 32559            NaN  White    Male  United-States  <=50K
# 32560           Wife  White  Female  United-States   >50K
#
# [32537 rows x 9 columns]

# %%
df["workclass"].value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
x=df.describe(include="all")
x
# Out:
#              age workclass      fnlwgt education  education_num  \
# count  32537.000     32537   32537.000     32537      31735.000
# unique       NaN         9         NaN        16            NaN
# top          NaN   Private         NaN   HS-grad            NaN
# freq         NaN     22673         NaN     10494            NaN
# mean      38.586       NaN  189780.849       NaN         10.084
# std       13.638       NaN  105556.471       NaN          2.575
# min       17.000       NaN   12285.000       NaN          1.000
# 25%       28.000       NaN  117827.000       NaN          9.000
# 50%       37.000       NaN  178356.000       NaN         10.000
# 75%       48.000       NaN  236993.000       NaN         12.000
# max       90.000       NaN 1484705.000       NaN         16.000
#
#             marital_status      occupation relationship   race    sex  \
# count                32537           32537        27473  32537  32537
# unique                   7              15            5      5      2
# top     Married-civ-spouse  Prof-specialty      Husband  White   Male
# freq                 14970            4136        13187  27795  21775
# mean                   NaN             NaN          NaN    NaN    NaN
# std                    NaN             NaN          NaN    NaN    NaN
# min                    NaN             NaN          NaN    NaN    NaN
# 25%                    NaN             NaN          NaN    NaN    NaN
# 50%                    NaN             NaN          NaN    NaN    NaN
# 75%                    NaN             NaN          NaN    NaN    NaN
# max                    NaN             NaN          NaN    NaN    NaN
#
#         capital_gain  capital_loss  hours_per_week native_country salary
# count      32537.000     32537.000       32537.000          32537  32537
# unique           NaN           NaN             NaN             42      2
# top              NaN           NaN             NaN  United-States  <=50K
# freq             NaN           NaN             NaN          29153  24698
# mean        1078.444        87.368          40.440            NaN    NaN
# std         7387.957       403.102          12.347            NaN    NaN
# min            0.000         0.000           1.000            NaN    NaN
# 25%            0.000         0.000          40.000            NaN    NaN
# 50%            0.000         0.000          40.000            NaN    NaN
# 75%            0.000         0.000          45.000            NaN    NaN
# max        99999.000      4356.000          99.000            NaN    NaN

# %%
# Your Code is Here

y=x[["workclass","education","marital_status","occupation","relationship","race","sex","native_country","salary"]].loc[["count","unique","top","freq"]].T
y
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/WspBGfZ/US-Citicens3.png)

# %% [markdown]
# **Assign the Columns (Features) of object data type as** **``"object_col"``**

# %%
# Your Code is Here

y.index
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %% [raw]
# Desired Output:
#
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'gender', 'native_country', 'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df[col].value_counts(dropna=False))
    print("--"*20)

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
# Your Code is Here
df.eq("?").any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [raw]
# Desired Output:
#
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# gender            False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## Salary (Target Feature)

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
# Your Code is Here

df["salary"].value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
import seaborn as sns 
import matplotlib 
import matplotlib.pyplot as plt

# %%
a= df["salary"].value_counts().index

# %%
b = df["salary"].value_counts().values

# %%
# Your Code is Here

fig,ax = plt.subplots(figsize=(12,7))
ax = sns.barplot(a,b)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.35, p.get_height()+1))
    
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9qwrtB1/US-Citicens4.png)

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
# Your Code is Here

df["salary"].value_counts(normalize=True)
# Out:
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %% [raw]
# Desired Output:
#
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
t = df["salary"].value_counts(normalize=True).index

# %%
w = df["salary"].value_counts(normalize=True).values
w
# Out:
# array([0.75907428, 0.24092572])

# %%
# Is there a relationship between race and salary?
df.groupby("race")["salary"].value_counts(normalize=True) * 100

#Yes, there is a relationship between salary and ethnicity. 
#If you're white, you have a higher potential to earn a salary more than 50K dollars 
#when compared to a black man
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    88.424
#                     >50K     11.576
# Asian-Pac-Islander  <=50K    73.410
#                     >50K     26.590
# Black               <=50K    87.604
#                     >50K     12.396
# Other               <=50K    90.775
#                     >50K      9.225
# White               <=50K    74.402
#                     >50K     25.598
# Name: salary, dtype: float64

# %%
#Now, we will try to analyze the relationship between age and salary.
#Our question is that "does the salary increase as age increases?"
#1st step
q=df[(df["age"] < 25)]["salary"].sample(50)
w = pd.DataFrame(q)
w.value_counts()
# Out:
# salary
# <=50K     49
# >50K       1
# dtype: int64

# %%
#Second step
p = df[df["age"] > 65][["salary"]].sample(50)
p.value_counts()

#Based on our calculations we can conclude that there is a strong positive relationship
#between age and salary. As age increases salary increases too.
# Out:
# salary
# <=50K     38
# >50K      12
# dtype: int64

# %%
df.groupby("race")[["salary"]].value_counts(normalize=True).loc[["Black","White"]]
# Out:
# race   salary
# Black  <=50K    0.876
#        >50K     0.124
# White  <=50K    0.744
#        >50K     0.256
# dtype: float64

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
a = df["salary"].value_counts().index
a
# Out:
# Index(['<=50K', '>50K'], dtype='object')

# %%
b = df["salary"].value_counts().values
b
# Out:
# array([24698,  7839], dtype=int64)

# %%
colors=["lightblue", "yellow"]

# %%
myexplode=[0,0.3]

# %%
# Your Code is Here

plt.pie(x=b, labels=a, explode=myexplode,labeldistance=0.4,autopct="%.1f",colors=colors)

plt.title("Percentage of Income-Levels", size=30);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/8YFvBrq/US-Citices5.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Firstly, we have to emphasize that most people have a salary under 50K dollars annually.
#              Secondly, there is a relationship between salary and ethnicity. If you're a member of white ethnicity, you have a                higher potential to earn a salary more than 50K dollars when compared to a black man.
#              Lastly, we can conclude that there is a strong positive relationship between age and salary. As age increases                    salary increases too.

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ## age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
c1 = "blue"

# %%
# Your Code is Here
sns.boxplot(df["age"])
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JKKwy5K/US-Citizens6.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

plt.figure(figsize=(12,6))
sns.histplot(x=df["age"], data=df, kde=True, bins=20);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JcJ9cyp/US-Citizens7.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
df.describe()["age"]
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
sns.boxplot(data=df, y="age", x="salary");

# %%
;
# Out:
# ''

# %%
# Your Code is Here
sns.boxplot(data=df, y="age", x="salary");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/64tBVNT/US-Citizens8.png)

# %%
# Your Code is Here

sns.histplot(x=df["age"], hue=df["salary"], bins=20, kde=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/q5P0sVf/US-Citizens9.png)

# %%
# Your Code is Hereplt.figure(figsize=(12,12))
sns.displot(data=df, x=df["age"], hue=df["salary"], kind="kde", fill=True)

plt.show()

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here
df.groupby("salary").describe()["age"]
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xYYZcZZ/US-Citizens11.png)

# %%
sns.barplot(x=df["salary"], y=df["age"]);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :As age increaeses salary also increases. So they have a positive partially strong relationship.

# %% [markdown]
# ## fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

plt.figure(figsize=(12,8))
sns.boxplot(x=df["fnlwgt"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x2TtkzH/US-Citizens12.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.distplot(df, x=df["fnlwgt"], hist=False, kde_kws={"shade":True});

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/ZmMV8nv/US-Citizens13.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
df["fnlwgt"].describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [raw]
# Desired Output:
#
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(data=df, y="fnlwgt", x="salary");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/ZxJS7JW/US-Citizens14.png)

# %%
# Your Code is Here

sns.displot(data=df, x=df["fnlwgt"], hue=df["salary"], kind="kde", fill=True)

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TgygLrz/US-Citizens15.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here
df.groupby("salary").describe()["capital_gain"]
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/LzWqdBf/US-Citizens16.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ...............

# %% [markdown]
# ## capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
sns.boxplot(x=df["capital_gain"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6Xj1TCz/US-Citizens17.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Heresns.
sns.distplot(df, x=df["capital_gain"], hist=False, kde_kws={"shade":True});

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/X3nW72Q/US-Citizens18.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.describe()["capital_gain"]
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(x=df["salary"], y=df["capital_gain"]);

# %%
sns.displot(data=df, x=df["capital_gain"]);

# %%
# Your Code is Here
sns.displot(data=df,x=df["capital_gain"], hue=df["salary"], kind="kde");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/h7DKvLY/20.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df.groupby("salary").describe()
# Out:
#              age                                                     fnlwgt  \
#            count   mean    std    min    25%    50%    75%    max     count
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000 24698.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000  7839.000
#
#                                                                          \
#              mean        std       min        25%        50%        75%
# salary
# <=50K  190345.927 106487.413 12285.000 117606.000 179465.000 238968.250
# >50K   188000.481 102554.464 14878.000 119100.000 176063.000 230969.000
#
#                    education_num                                          \
#                max         count   mean   std   min    25%    50%    75%
# salary
# <=50K  1484705.000     24104.000  9.599 2.439 1.000  9.000  9.000 10.000
# >50K   1226583.000      7631.000 11.616 2.388 2.000 10.000 12.000 13.000
#
#               capital_gain                                             \
#           max        count     mean       std   min   25%   50%   75%
# salary
# <=50K  16.000    24698.000  148.885   963.558 0.000 0.000 0.000 0.000
# >50K   16.000     7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000
#
#                  capital_loss                                          \
#              max        count    mean     std   min   25%   50%   75%
# salary
# <=50K  41310.000    24698.000  53.190 310.890 0.000 0.000 0.000 0.000
# >50K   99999.000     7839.000 195.051 595.555 0.000 0.000 0.000 0.000
#
#                 hours_per_week
#             max          count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  4356.000      24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K   3683.000       7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %%
# Your Code is Here
df.groupby("salary").describe()["capital_gain"]
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mzYxTD4/21.png)

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
# Your Code is Here

df.groupby("salary").describe()["capital_gain"]
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/r3mdBkK/22.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ...........................

# %% [markdown]
# ## capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
sns.boxplot(x=df["capital_loss"]);

# %%
# Your Code is Here

sns.boxplot(x=df["capital_loss"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Db3XHKz/23.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
sns.distplot(a=df["capital_loss"], kde=True,kde_kws={"shade":True});

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/z7P15zX/24.png)

# %% [markdown]
# **Check the statistical values**

# %%
df.describe()["capital_loss"]
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %%
# Your Code is Here

df.describe()["capital_loss"]
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
sns.boxplot(x=df["salary"], y=df["capital_loss"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Dr7Bv9V/25.png)

# %%
# Your Code is Here

sns.displot(data=df, x=df["capital_loss"], hue="salary", kind="kde");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4Vg5Zyy/26.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary").describe()["capital_loss"]
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/h9DTKNW/27.png)

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
# Your Code is Here

df.groupby("salary").describe()
# Out:
#              age                                                     fnlwgt  \
#            count   mean    std    min    25%    50%    75%    max     count
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000 24698.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000  7839.000
#
#                                                                          \
#              mean        std       min        25%        50%        75%
# salary
# <=50K  190345.927 106487.413 12285.000 117606.000 179465.000 238968.250
# >50K   188000.481 102554.464 14878.000 119100.000 176063.000 230969.000
#
#                    education_num                                          \
#                max         count   mean   std   min    25%    50%    75%
# salary
# <=50K  1484705.000     24104.000  9.599 2.439 1.000  9.000  9.000 10.000
# >50K   1226583.000      7631.000 11.616 2.388 2.000 10.000 12.000 13.000
#
#               capital_gain                                             \
#           max        count     mean       std   min   25%   50%   75%
# salary
# <=50K  16.000    24698.000  148.885   963.558 0.000 0.000 0.000 0.000
# >50K   16.000     7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000
#
#                  capital_loss                                          \
#              max        count    mean     std   min   25%   50%   75%
# salary
# <=50K  41310.000    24698.000  53.190 310.890 0.000 0.000 0.000 0.000
# >50K   99999.000     7839.000 195.051 595.555 0.000 0.000 0.000 0.000
#
#                 hours_per_week
#             max          count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  4356.000      24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K   3683.000       7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/gJzQvmD/28.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ..................

# %% [markdown]
# ## hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Your Code is Here
sns.boxplot(x=df["hours_per_week"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TkNCRYY/29.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
sns.kdeplot(x=df["hours_per_week"], shade=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/tsp5GXb/30.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
df.describe()["hours_per_week"]
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
sns.boxplot(x=df["salary"], y=df["hours_per_week"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4RhSct7/31.png)

# %%
# Your Code is Here
sns.kdeplot(x=df["hours_per_week"], hue=df["salary"], shade=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/pbbVnMG/32.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary").describe()["hours_per_week"]
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6NbWfzz/33.png)

# %%
sns.barplot(x=df["salary"], y=df["hours_per_week"], hue=df["race"]);

# %%
#sns.barplot(x=df["salary"], y=df["age"]);

# %%
sns.lineplot(x="age", y="hours_per_week", data=df);

# %%
sns.scatterplot(x="hours_per_week", y="age", data=df);

# %%
sns.barplot(x=df["salary"], y=df["hours_per_week"]);

# %%
df.sample(50)[["salary","hours_per_week"]]
# Out:
#       salary  hours_per_week
# 4027   <=50K              50
# 25622   >50K              40
# 21261   >50K              40
# 395    <=50K              40
# 17638   >50K              40
# 4641    >50K              60
# 4079   <=50K              38
# 28086  <=50K              40
# 9529    >50K              40
# 9421   <=50K              55
# 23772  <=50K              20
# 28689  <=50K              40
# 22092  <=50K              40
# 2135   <=50K              40
# 26060   >50K              40
# 24203   >50K              35
# 7651   <=50K              40
# 32393  <=50K              40
# 28550   >50K              40
# 10751  <=50K              40
# 17536  <=50K              40
# 24655  <=50K              40
# 23766  <=50K              20
# 15104   >50K              50
# 18907  <=50K              47
# 9660    >50K              40
# 8679   <=50K              50
# 27005  <=50K              42
# 21262  <=50K              20
# 16724  <=50K              50
# 15637  <=50K              40
# 20662   >50K              55
# 8304   <=50K              40
# 6419    >50K              35
# 31426  <=50K              60
# 20994  <=50K              40
# 23459   >50K              50
# 6157   <=50K              45
# 3034   <=50K              60
# 27640   >50K              65
# 8372   <=50K              35
# 27183  <=50K              50
# 8009   <=50K              30
# 6243   <=50K              40
# 27479  <=50K              32
# 5447   <=50K              32
# 9051   <=50K              40
# 5111   <=50K              18
# 30954   >50K              50
# 28866   >50K              37

# %%
#Calculation of Alpha
df[df["salary"] == ">50K"][["hours_per_week"]].sample(20)
# Out:
#        hours_per_week
# 7355               55
# 22978              40
# 10079              50
# 25641              55
# 18021              48
# 7215               45
# 6661               40
# 30393              40
# 31992              52
# 29187              99
# 25913              70
# 15579              40
# 2726               40
# 10792              50
# 22146              50
# 31496              50
# 4636               40
# 25012              45
# 23087              37
# 22620              45

# %%
#calculation of T
df[df["salary"] == "<=50K"][["hours_per_week"]].sample(20)
# Out:
#        hours_per_week
# 25597              20
# 21852              91
# 30191              45
# 12366              12
# 9028                8
# 18384               5
# 25014              40
# 21542              25
# 30624              10
# 18880              36
# 31057              35
# 13179              40
# 9721               40
# 18037              20
# 9797               40
# 30412              32
# 19629              40
# 19554              40
# 2169               30
# 21211              20

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Based on our statistical calculations above, we can conclude that working hours per week and salary have a positive strong relationship. When your working hours per week increases your salary also increases. Calculation of T and Alpha proves our statement.

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/N7Fz4hg/34.png)

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Your Code is Here

df["education"].value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %% [raw]
# Desired Output:
#
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
# Your Code is Here
df["education_num"].value_counts()
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %% [raw]
# Desired Output:
#
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
# Your Code is Here
df.groupby("education")["education_num"].value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# Name: education_num, dtype: int64

# %% [raw]
# Desired Output:
#
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# Name: education_num, dtype: int64

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
# Your Code is Here

sns.countplot(x=df["education"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5xc31HR/35.png)

# %%
# Your Code is Here
sns.countplot(x=df["education_num"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6HWtNN6/36.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
# Your Code is Here
df.groupby("education")["salary"].value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(12,8))
sns.countplot(x=df["education"], hue=df["salary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qxZXX1y/37.png)

# %%
# Your Code is Here

df.groupby("education_num")["salary"].value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
#                <=50K      103
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
#                <=50K      103
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["education_num"], hue=df["salary"])
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2M0BYyk/38.png)

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
# Your Code is Here
sns.boxplot(x=df["salary"], y=df["education_num"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mSBNzKw/39.png)

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
df["education"].replace({"Preschool":"low_level_grade", "1st-4th":"low_level_grade","5th-6th":"low_level_grade","7th-8th":"low_level_grade","9th":"low_level_grade","10th":"low_level_grade","11th":"low_level_grade","12th":"low_level_grade"}, inplace=True)

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %%
df3["education"].replace({"Bachelors":"high_level_grade", "Masters":"high_level_grade","Prof-school":"high_level_grade","Doctorate":"high_level_grade"}, inplace=True)

# %%
df2["education"].replace({"Bachelors":"high_level_grade", "Masters":"high_level_grade","Prof-school":"high_level_grade","Doctorate":"high_level_grade"}, inplace=True)

# %%
df["education_summary"] = df["education"].apply(mapping_education)
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
#         education_summary
# 0        high_level_grade
# 1        high_level_grade
# 2      medium_level_grade
# 3         low_level_grade
# 4        high_level_grade
# ...                   ...
# 32556  medium_level_grade
# 32557  medium_level_grade
# 32558  medium_level_grade
# 32559  medium_level_grade
# 32560  medium_level_grade
#
# [32561 rows x 16 columns]

# %%
# Your Code is Here
df["education_summary"].value_counts(dropna=False)
# Out:
# medium_level_grade    20241
# high_level_grade       8067
# low_level_grade        4253
# Name: education_summary, dtype: int64

# %% [raw]
# Desired Output:
#
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
df["education_summary"] = df3["education_summary"]
df
# Out:
#        age         workclass  fnlwgt           education  education_num  \
# 0       39         State-gov   77516    high_level_grade         13.000
# 1       50  Self-emp-not-inc   83311    high_level_grade         13.000
# 2       38           Private  215646  medium_level_grade          9.000
# 3       53           Private  234721     low_level_grade          7.000
# 4       28           Private  338409    high_level_grade         13.000
# ...    ...               ...     ...                 ...            ...
# 32556   27           Private  257302  medium_level_grade         12.000
# 32557   40           Private  154374  medium_level_grade          9.000
# 32558   58           Private  151910  medium_level_grade          9.000
# 32559   22           Private  201490  medium_level_grade          9.000
# 32560   52      Self-emp-inc  287927  medium_level_grade          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical        unknown  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
#         education_summary
# 0        high_level_grade
# 1        high_level_grade
# 2      medium_level_grade
# 3         low_level_grade
# 4        high_level_grade
# ...                   ...
# 32556  medium_level_grade
# 32557  medium_level_grade
# 32558  medium_level_grade
# 32559  medium_level_grade
# 32560  medium_level_grade
#
# [32537 rows x 16 columns]

# %%
# By using "mapping_education" def function above, create a new column named "education_summary"

# Your Code is Here
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

    
    
df["education_summary"] = df["education"].apply(mapping_education)
df
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
#         education_summary
# 0        high_level_grade
# 1        high_level_grade
# 2      medium_level_grade
# 3         low_level_grade
# 4        high_level_grade
# ...                   ...
# 32556  medium_level_grade
# 32557  medium_level_grade
# 32558  medium_level_grade
# 32559  medium_level_grade
# 32560  medium_level_grade
#
# [32561 rows x 16 columns]

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
# Your Code is Here

sns.countplot(x=df["education_summary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cx3Dzn1/40.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("education_summary")["salary"].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4158
#                     >50K       3909
# low_level_grade     <=50K      4009
#                     >50K        244
# medium_level_grade  <=50K     16553
#                     >50K       3688
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
df.groupby("education_summary")["salary"].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4158
#                     >50K       3909
# low_level_grade     <=50K      4009
#                     >50K        244
# medium_level_grade  <=50K     16553
#                     >50K       3688
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.countplot(x=df["education_summary"], hue=df["salary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/tXk04LJ/41.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("education_summary")["salary"].value_counts(normalize=True)
# Out:
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
e=df.groupby("education_summary")["salary"].value_counts(normalize=True)[["medium_level_grade"]].index
e
# Out:
# MultiIndex([('medium_level_grade', '<=50K'),
#             ('medium_level_grade',  '>50K')],
#            names=['education_summary', 'salary'])

# %%
e=df.groupby("education_summary")["salary"].value_counts(normalize=True)[["medium_level_grade"]].index
e
# Out:
# MultiIndex([('medium_level_grade', '<=50K'),
#             ('medium_level_grade',  '>50K')],
#            names=['education_summary', 'salary'])

# %%
f=df.groupby("education_summary")["salary"].value_counts(normalize=True)[["medium_level_grade"]].values
# Out:
# array([0.81779556, 0.18220444])

# %%
plt.figure(figsize=(20,10))
                   

plt.subplot(1,3,1)
plt.pie(b, labels=a, labeldistance=0.7, autopct="%.1f")
plt.title("high_level_grade", size=20)


plt.subplot(1,3,2)
plt.pie(d, labels=c, labeldistance=0.7, autopct="%.1f")
plt.title("high_level_grade", size=20)


plt.subplot(1,3,3)
plt.pie(f, labels=e, labeldistance=0.7, autopct="%.1f")
plt.title("medium_level_grade", size=20);

# %%
#fig,ax=plt.subplots(1,3)

#ax1.pie(b, labels=a, labeldistance=0.7, autpct="%.1f")
#ax2.pie(d, labels=c, labeldistance=0.7, autpct="%.1f")
#ax3.pie(f, labels=e, labeldistance=0.7, autpct="%.1f")

#plt.show()

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9W6kXc6/42.png)

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# Your Code is Here
sns.countplot(x=df["salary"], hue=df["education_summary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/K9xLxvF/43.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("salary")["education_summary"].value_counts(normalize=True)
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/42pnNPc/44.png)

# %%
# Your Code is Here
a = df.groupby("salary")["education_summary"].value_counts(normalize=True)
b = pd.DataFrame(a)
b.rename(columns={"salary":"salary", "education_summary":"education_summary", "education_summary":"percentage"}, inplace=True)
c= b.reset_index()
c.sort_values(by=["salary","education_summary"])
# Out:
#   salary   education_summary  percentage
# 1  <=50K    high_level_grade       0.168
# 2  <=50K     low_level_grade       0.162
# 0  <=50K  medium_level_grade       0.670
# 3   >50K    high_level_grade       0.499
# 5   >50K     low_level_grade       0.031
# 4   >50K  medium_level_grade       0.470

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/jHYrhz8/45.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5BnYV6h/46.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** People who get more than 50K mostly have a higher education compared to other member of the community. Based on this assumption, it can be said that there is a strong and positive relationship between your education level and salary.

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
df3 = df.copy()
df3.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Your Code is Here
df["marital_status"].value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %% [raw]
# Desired Output:
#
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
# Your Code is Here

df["relationship"].value_counts()
# Out:
# Husband           13187
# Not-in-family      8292
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %% [raw]
# Desired Output:
#
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"

# Your Code is Here

df["relationship"] = df["relationship"].fillna("unknown")

# %%
# Your Code is Here

df.groupby("relationship")["marital_status"].value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Name: marital_status, dtype: int64

# %% [raw]
# Desired Output:
#
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: marital_status, dtype: int64

# %% [markdown]
# **Assessment :** ........

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
# Your Code is Here
sns.countplot(x=df["marital_status"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/1RNHVvj/47.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("marital_status")["salary"].value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["marital_status"], hue=df["salary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qjNhW9h/48.png)

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
df3.replace({"Never-married":"unmarried", "Divorced":"unmarried", "Separated":"unmarried", "Widowed":"unmarried"}, inplace=True)

# %%
df3.replace({"Married-civ-spouse":"married", "Married-AF-spouse":"married", "Married-spouse-absent":"married"}, inplace=True)

# %%
df.replace({"Married-civ-spouse":"married", "Married-AF-spouse":"married", "Married-spouse-absent":"married"}, inplace=True)

# %%
df.replace({"Never-married":"unmarried", "Divorced":"unmarried", "Separated":"unmarried", "Widowed":"unmarried"}, inplace=True)

# %%
#The creation of column called "marital_status_summary"

df["marital_status"] = df2["marital_status"]
df
# Out:
#        age         workclass  fnlwgt           education  education_num  \
# 0       39         State-gov   77516    high_level_grade         13.000
# 1       50  Self-emp-not-inc   83311    high_level_grade         13.000
# 2       38           Private  215646  medium_level_grade          9.000
# 3       53           Private  234721     low_level_grade          7.000
# 4       28           Private  338409    high_level_grade         13.000
# ...    ...               ...     ...                 ...            ...
# 32556   27           Private  257302  medium_level_grade         12.000
# 32557   40           Private  154374  medium_level_grade          9.000
# 32558   58           Private  151910  medium_level_grade          9.000
# 32559   22           Private  201490  medium_level_grade          9.000
# 32560   52      Self-emp-inc  287927  medium_level_grade          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical        unknown  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
#         education_summary marital_status_summary
# 0        high_level_grade              unmarried
# 1        high_level_grade                married
# 2      medium_level_grade              unmarried
# 3         low_level_grade                married
# 4        high_level_grade                married
# ...                   ...                    ...
# 32556  medium_level_grade                married
# 32557  medium_level_grade                married
# 32558  medium_level_grade              unmarried
# 32559  medium_level_grade              unmarried
# 32560  medium_level_grade                married
#
# [32537 rows x 17 columns]

# %%
# Your Code is Here
df["marital_status_summary"].value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status_summary, dtype: int64

# %% [raw]
# Desired Output:
#
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"

# Your Code is Here
#The column called "marital_status_summary" was created above in a different way.

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
# Your Code is Here

sns.countplot(x=df["marital_status_summary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/wRjj6Bx/49.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("marital_status_summary")["salary"].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.countplot(x=df["marital_status_summary"], hue=df["salary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0JtYnFb/50.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %% [raw]
# Desired Output:
#
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TYxT5Zz/51.png)

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["marital_status_summary"].value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
# Your Code is Here
sns.countplot(x=df["salary"], hue=df["marital_status_summary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/YWjjsZP/52.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
# Your Code is Here
a = df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
b = pd.DataFrame(a)
b.rename(columns={"salary":"salary", "marital_status_summary":"marital_status_summary","marital_status_summary":"percentage"},inplace=True)
c=b.reset_index()
c
# Out:
#   salary marital_status_summary  percentage
# 0  <=50K              unmarried       0.649
# 1  <=50K                married       0.351
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Swb4rb7/v53.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cJxmqwG/54.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Surprisingly, people getting more than 50K are mostly married. So as soon as possible I need to think for getting married:))))))

# %% [markdown]
# ## workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Your Code is Here

df["workclass"].value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %% [raw]
# Desired Output:
#
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["workclass"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/NmKTp84/55.png)

# %%
df.sample()
# Out:
#        age workclass  fnlwgt     education  education_num      marital_status  \
# 10658   57   Private  112840  Some-college         10.000  Married-civ-spouse
#
#       occupation relationship   race   sex  capital_gain  capital_loss  \
# 10658      Sales      Husband  White  Male             0             0
#
#        hours_per_week native_country salary
# 10658              50  United-States   >50K

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"

# Your Code is Here

df["workclass"].replace(to_replace="?", value="unknown", inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
df.describe(include="all")
# Out:
#              age workclass      fnlwgt education  education_num  \
# count  32537.000     32537   32537.000     32537      31735.000
# unique       NaN         9         NaN        16            NaN
# top          NaN   Private         NaN   HS-grad            NaN
# freq         NaN     22673         NaN     10494            NaN
# mean      38.586       NaN  189780.849       NaN         10.084
# std       13.638       NaN  105556.471       NaN          2.575
# min       17.000       NaN   12285.000       NaN          1.000
# 25%       28.000       NaN  117827.000       NaN          9.000
# 50%       37.000       NaN  178356.000       NaN         10.000
# 75%       48.000       NaN  236993.000       NaN         12.000
# max       90.000       NaN 1484705.000       NaN         16.000
#
#             marital_status      occupation relationship   race    sex  \
# count                32537           32537        32537  32537  32537
# unique                   7              15            6      5      2
# top     Married-civ-spouse  Prof-specialty      Husband  White   Male
# freq                 14970            4136        13187  27795  21775
# mean                   NaN             NaN          NaN    NaN    NaN
# std                    NaN             NaN          NaN    NaN    NaN
# min                    NaN             NaN          NaN    NaN    NaN
# 25%                    NaN             NaN          NaN    NaN    NaN
# 50%                    NaN             NaN          NaN    NaN    NaN
# 75%                    NaN             NaN          NaN    NaN    NaN
# max                    NaN             NaN          NaN    NaN    NaN
#
#         capital_gain  capital_loss  hours_per_week native_country salary
# count      32537.000     32537.000       32537.000          32537  32537
# unique           NaN           NaN             NaN             42      2
# top              NaN           NaN             NaN  United-States  <=50K
# freq             NaN           NaN             NaN          29153  24698
# mean        1078.444        87.368          40.440            NaN    NaN
# std         7387.957       403.102          12.347            NaN    NaN
# min            0.000         0.000           1.000            NaN    NaN
# 25%            0.000         0.000          40.000            NaN    NaN
# 50%            0.000         0.000          40.000            NaN    NaN
# 75%            0.000         0.000          45.000            NaN    NaN
# max        99999.000      4356.000          99.000            NaN    NaN

# %%
#X calculation
a = df[df["workclass"] == "Private"]["education"].value_counts()
u=pd.DataFrame(a)
u
# Out:
#               education
# HS-grad            7773
# Some-college       5086
# Bachelors          3549
# Assoc-voc          1005
# 11th                923
# Masters             893
# Assoc-acdm          729
# 10th                695
# 7th-8th             423
# 9th                 387
# 12th                333
# 5th-6th             265
# Prof-school         257
# Doctorate           181
# 1st-4th             134
# Preschool            40

# %%
#Can we say that whose workclass is private mostly does not have a solid background in terms of education. Yes, when we have 
#a look at the data frame called u we see that most of these people do not have a powerful educational bakcground.

# %%
t=df[df["workclass"] == "Private"][["education","salary"]].value_counts()
q=pd.DataFrame(t)
q.rename(columns={"education":"edu", "salary":"salary", 0:"toplam"}, inplace=True)
q
# Out:
#                      toplam
# education    salary
# HS-grad      <=50K     6655
# Some-college <=50K     4164
# Bachelors    <=50K     2054
#              >50K      1495
# HS-grad      >50K      1118
# Some-college >50K       922
# 11th         <=50K      878
# Assoc-voc    <=50K      749
# 10th         <=50K      648
# Assoc-acdm   <=50K      559
# Masters      >50K       534
# 7th-8th      <=50K      405
# 9th          <=50K      369
# Masters      <=50K      359
# 12th         <=50K      310
# 5th-6th      <=50K      258
# Assoc-voc    >50K       256
# Prof-school  >50K       171
# Assoc-acdm   >50K       170
# Doctorate    >50K       132
# 1st-4th      <=50K      129
# Prof-school  <=50K       86
# Doctorate    <=50K       49
# 10th         >50K        47
# 11th         >50K        45
# Preschool    <=50K       40
# 12th         >50K        23
# 9th          >50K        18
# 7th-8th      >50K        18
# 5th-6th      >50K         7
# 1st-4th      >50K         5

# %%
#Can we say that among people whose workclass is private as educational bakcground increases salary increases too? Yes, we can
#say that.

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
# Your Code is Here
df.groupby("workclass")["salary"].value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Without-pay       <=50K        14
# unknown           <=50K      1645
#                   >50K        191
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(12,6))
sns.countplot(x=df["workclass"], hue=df["salary"])
plt.xlabel("workclass")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/bPnNvsn/56.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby("workclass")["salary"].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Without-pay       <=50K    1.000
# unknown           <=50K    0.896
#                   >50K     0.104
# Name: salary, dtype: float64

# %% [raw]
# Desired Output:
#
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
df.groupby("workclass")["salary"].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Without-pay       <=50K    1.000
# unknown           <=50K    0.896
#                   >50K     0.104
# Name: salary, dtype: float64

# %%
df5 = df.groupby("workclass")["salary"].value_counts(normalize=True)
x = pd.DataFrame(df5)
x.rename(columns={"workclass":"workclass", "salary":"salary", "salary":"percentage"}, inplace=True)
x.reset_index()
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13       Without-pay  <=50K       1.000
# 14           unknown  <=50K       0.896
# 15           unknown   >50K       0.104

# %%
# Your Code is Here
df5 = df.groupby("workclass")["salary"].value_counts(normalize=True)
x = pd.DataFrame(df5)
x.rename(columns={"workclass":"workclass", "salary":"salary", "salary":"percentage"}, inplace=True)
y = x.reset_index()
y
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13       Without-pay  <=50K       1.000
# 14           unknown  <=50K       0.896
# 15           unknown   >50K       0.104

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/8YvM14M/57.png)

# %%
# Your Code is Here
fig,ax= plt.subplots(figsize=(12,8))
ax=sns.barplot(x=y["workclass"], y=round(y["percentage"],2), hue=y["salary"])
for i in ax.patches:
    ax.annotate(i.get_height(), (i.get_x()+0.1,i.get_height()))

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/NFN5q04/58.png)

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["workclass"].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         unknown               191
# Name: workclass, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
# Your Code is Here
sns.countplot(x=df["salary"], hue=df["workclass"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/98V8zkN/59.png)

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["workclass"].value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         unknown            0.024
# Name: workclass, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
# Your Code is Here
df6 = df.groupby("salary")["workclass"].value_counts(normalize=True)
u = pd.DataFrame(df6)
u.rename(columns={"salary":"salary", "workclass":"workclass", "workclass":"percentage"}, inplace=True)
k=u.reset_index()
ü = k.sort_values(["workclass"], ascending=True)
ü
# Out:
#    salary         workclass  percentage
# 5   <=50K       Federal-gov       0.024
# 13   >50K       Federal-gov       0.047
# 3   <=50K         Local-gov       0.060
# 12   >50K         Local-gov       0.079
# 8   <=50K      Never-worked       0.000
# 0   <=50K           Private       0.717
# 9    >50K           Private       0.633
# 6   <=50K      Self-emp-inc       0.020
# 11   >50K      Self-emp-inc       0.079
# 1   <=50K  Self-emp-not-inc       0.074
# 10   >50K  Self-emp-not-inc       0.092
# 4   <=50K         State-gov       0.038
# 14   >50K         State-gov       0.045
# 7   <=50K       Without-pay       0.001
# 2   <=50K           unknown       0.067
# 15   >50K           unknown       0.024

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/QcdnXpk/60.png)

# %%
# Your Code is Here
fig, ax = plt.subplots()

ax=sns.barplot(x=ü["salary"], y=round(ü["percentage"],3), hue=ü["workclass"])

for i in ax.patches:
    ax.annotate(i.get_height(), (i.get_x(),i.get_height()+0.01))
    
    
plt.legend(loc="upper right")
    
plt.show();

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Kz5BDBj/61.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Basically, based on our calculations related to the workclass feature we can reach to two important outcomes. First outcome is that whose workclass is private mostly does not have a solid background in terms of education. Our second conclusion we can get from our calculations is that  among people whose workclass is private as educational bakcground increases salary increases too.

# %% [markdown]
# ## occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df["occupation"].value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %% [raw]
# Desired Output:
#
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["occupation"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/F3qqLjS/62.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here
df["occupation"].replace(to_replace="?", value="unknown", inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("occupation")["salary"].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# unknown            <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unknown            <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["occupation"], hue=df["salary"])
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/RhkhQCW/63.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
# Your Code is Here
df.groupby("occupation")["salary"].value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
#                    >50K     0.200
# unknown            <=50K    0.896
#                    >50K     0.104
# Name: salary, dtype: float64

# %% [raw]
# Desired Output:
#
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
#                    >50K     0.200
# Unknown            <=50K    0.896
#                    >50K     0.104
# Name: salary, dtype: float64

# %%
# Your Code is Here

b = df.groupby("occupation")["salary"].value_counts(normalize=True)
a = pd.DataFrame(b)
a.rename(columns={"occupation":"occupation", "salary":"salary", "salary":"percentage"}, inplace=True)
q =a.reset_index()
q
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# 22              Sales  <=50K       0.731
# 23              Sales   >50K       0.269
# 24       Tech-support  <=50K       0.695
# 25       Tech-support   >50K       0.305
# 26   Transport-moving  <=50K       0.800
# 27   Transport-moving   >50K       0.200
# 28            unknown  <=50K       0.896
# 29            unknown   >50K       0.104

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mb7JS3n/64.png)

# %%
# Your Code is Here

fig, ax = plt.subplots()

ax=sns.barplot(x=q["occupation"], y=round(q["percentage"],2), hue=q["salary"])

for i in ax.patches:
    ax.annotate(i.get_height(), (i.get_x(),i.get_height()+0.01))
    
plt.xticks(rotation=90)
plt.legend(loc="upper right")
    
plt.show();

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/sW2b8wL/65.png)

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Your Code is Here
df.groupby("salary")["occupation"].value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         unknown               191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: occupation, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: occupation, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["salary"], hue=df["occupation"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cvHS3FH/66.png)

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here
df.groupby("salary")["occupation"].value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
#         Handlers-cleaners   0.011
#         Armed-Forces        0.000
#         Priv-house-serv     0.000
# Name: occupation, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
#         Handlers-cleaners   0.011
#         Armed-Forces        0.000
#         Priv-house-serv     0.000
# Name: occupation, dtype: float64

# %%
a=df.groupby("salary")["occupation"].value_counts(normalize=True)
b=pd.DataFrame(a)
b.rename(columns={"salary":"salary", "occupation":"occupation", "occupation":"percentage"}, inplace=True)
q=b.reset_index()
q
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 1   <=50K       Craft-repair       0.128
# 2   <=50K      Other-service       0.128
# 3   <=50K              Sales       0.108
# 4   <=50K     Prof-specialty       0.092
# 5   <=50K    Exec-managerial       0.085
# 6   <=50K  Machine-op-inspct       0.071
# 7   <=50K            unknown       0.067
# 8   <=50K  Handlers-cleaners       0.052
# 9   <=50K   Transport-moving       0.052
# 10  <=50K    Farming-fishing       0.036
# 11  <=50K       Tech-support       0.026
# 12  <=50K    Protective-serv       0.018
# 13  <=50K    Priv-house-serv       0.006
# 14  <=50K       Armed-Forces       0.000
# 15   >50K    Exec-managerial       0.251
# 16   >50K     Prof-specialty       0.237
# 17   >50K              Sales       0.125
# 18   >50K       Craft-repair       0.119
# 19   >50K       Adm-clerical       0.065
# 20   >50K   Transport-moving       0.041
# 21   >50K       Tech-support       0.036
# 22   >50K  Machine-op-inspct       0.032
# 23   >50K    Protective-serv       0.027
# 24   >50K            unknown       0.024
# 25   >50K      Other-service       0.017
# 26   >50K    Farming-fishing       0.015
# 27   >50K  Handlers-cleaners       0.011
# 28   >50K       Armed-Forces       0.000
# 29   >50K    Priv-house-serv       0.000

# %%
# Your Code is Here
q.sort_values(by=["salary","occupation"], ascending=True)
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 14  <=50K       Armed-Forces       0.000
# 1   <=50K       Craft-repair       0.128
# 5   <=50K    Exec-managerial       0.085
# 10  <=50K    Farming-fishing       0.036
# 8   <=50K  Handlers-cleaners       0.052
# 6   <=50K  Machine-op-inspct       0.071
# 2   <=50K      Other-service       0.128
# 13  <=50K    Priv-house-serv       0.006
# 4   <=50K     Prof-specialty       0.092
# 12  <=50K    Protective-serv       0.018
# 3   <=50K              Sales       0.108
# 11  <=50K       Tech-support       0.026
# 9   <=50K   Transport-moving       0.052
# 7   <=50K            unknown       0.067
# 19   >50K       Adm-clerical       0.065
# 28   >50K       Armed-Forces       0.000
# 18   >50K       Craft-repair       0.119
# 15   >50K    Exec-managerial       0.251
# 26   >50K    Farming-fishing       0.015
# 27   >50K  Handlers-cleaners       0.011
# 22   >50K  Machine-op-inspct       0.032
# 25   >50K      Other-service       0.017
# 29   >50K    Priv-house-serv       0.000
# 16   >50K     Prof-specialty       0.237
# 23   >50K    Protective-serv       0.027
# 17   >50K              Sales       0.125
# 21   >50K       Tech-support       0.036
# 20   >50K   Transport-moving       0.041
# 24   >50K            unknown       0.024

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7tK0PqX/67.png)

# %%
sns.countplot(x=df["salary"],hue=df["occupation"]);

# %%
df.groupby("salary")["occupation"].value_counts(normalize=True).index
# Out:
# MultiIndex([('<=50K',      'Adm-clerical'),
#             ('<=50K',      'Craft-repair'),
#             ('<=50K',     'Other-service'),
#             ('<=50K',             'Sales'),
#             ('<=50K',    'Prof-specialty'),
#             ('<=50K',   'Exec-managerial'),
#             ('<=50K', 'Machine-op-inspct'),
#             ('<=50K',           'unknown'),
#             ('<=50K', 'Handlers-cleaners'),
#             ('<=50K',  'Transport-moving'),
#             ('<=50K',   'Farming-fishing'),
#             ('<=50K',      'Tech-support'),
#             ('<=50K',   'Protective-serv'),
#             ('<=50K',   'Priv-house-serv'),
#             ('<=50K',      'Armed-Forces'),
#             ( '>50K',   'Exec-managerial'),
#             ( '>50K',    'Prof-specialty'),
#             ( '>50K',             'Sales'),
#             ( '>50K',      'Craft-repair'),
#             ( '>50K',      'Adm-clerical'),
#             ( '>50K',  'Transport-moving'),
#             ( '>50K',      'Tech-support'),
#             ( '>50K', 'Machine-op-inspct'),
#             ( '>50K',   'Protective-serv'),
#             ( '>50K',           'unknown'),
#             ( '>50K',     'Other-service'),
#             ( '>50K',   'Farming-fishing'),
#             ( '>50K', 'Handlers-cleaners'),
#             ( '>50K',      'Armed-Forces'),
#             ( '>50K',   'Priv-house-serv')],
#            names=['salary', 'occupation'])

# %% [markdown]
# # Is there a relationship between occupation, education and ,of course, salary? If yes, how strong is the relationship?

# %%
df.groupby("occupation")["salary"].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# unknown            <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %%
general_view = df[["education","occupation","salary"]]

# %%
general_view["education"].value_counts().values
# Out:
# array([10494,  7282,  5353,  1722,  1382,  1175,  1067,   933,   645,
#          576,   514,   433,   413,   332,   166,    50], dtype=int64)

# %%
#From this plotting below we can see that as education level increases the count of people who earn more than 50K also
#increases. To understand this statement, we can observe the education levels and their members who earn more than 50K 11th,HS-grad, Some-College
#and Bachelors respectively.
sns.countplot(x=general_view["education"], hue=general_view["salary"])
plt.xticks(rotation=90);

# %%
df[df["occupation"] == "Exec-managerial"]["education"].value_counts()
# Out:
# Bachelors       1369
# Some-college     878
# HS-grad          807
# Masters          501
# Assoc-voc        150
# Assoc-acdm       145
# Doctorate         55
# Prof-school       52
# 11th              34
# 10th              24
# 7th-8th           19
# 9th               13
# 12th              13
# 1st-4th            4
# 5th-6th            1
# Name: education, dtype: int64

# %%
df[df["occupation"] == "Sales"]["education"].value_counts()
# Out:
# HS-grad         1069
# Some-college    1009
# Bachelors        809
# Assoc-acdm       144
# 11th             144
# Masters          134
# Assoc-voc        106
# 10th              81
# 12th              47
# 9th               32
# 7th-8th           29
# Prof-school       18
# 5th-6th           12
# 1st-4th            8
# Doctorate          8
# Name: education, dtype: int64

# %%
df.groupby("occupation")["education"].value_counts()
# Out:
# occupation    education
# Adm-clerical  HS-grad         1365
#               Some-college    1279
#               Bachelors        506
#               Assoc-acdm       193
#               Assoc-voc        167
#                               ...
# unknown       5th-6th           30
#               Prof-school       18
#               Doctorate         15
#               1st-4th           12
#               Preschool          5
# Name: education, Length: 217, dtype: int64

# %%
q
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 1   <=50K       Craft-repair       0.128
# 2   <=50K      Other-service       0.128
# 3   <=50K              Sales       0.108
# 4   <=50K     Prof-specialty       0.092
# 5   <=50K    Exec-managerial       0.085
# 6   <=50K  Machine-op-inspct       0.071
# 7   <=50K            unknown       0.067
# 8   <=50K  Handlers-cleaners       0.052
# 9   <=50K   Transport-moving       0.052
# 10  <=50K    Farming-fishing       0.036
# 11  <=50K       Tech-support       0.026
# 12  <=50K    Protective-serv       0.018
# 13  <=50K    Priv-house-serv       0.006
# 14  <=50K       Armed-Forces       0.000
# 15   >50K    Exec-managerial       0.251
# 16   >50K     Prof-specialty       0.237
# 17   >50K              Sales       0.125
# 18   >50K       Craft-repair       0.119
# 19   >50K       Adm-clerical       0.065
# 20   >50K   Transport-moving       0.041
# 21   >50K       Tech-support       0.036
# 22   >50K  Machine-op-inspct       0.032
# 23   >50K    Protective-serv       0.027
# 24   >50K            unknown       0.024
# 25   >50K      Other-service       0.017
# 26   >50K    Farming-fishing       0.015
# 27   >50K  Handlers-cleaners       0.011
# 28   >50K       Armed-Forces       0.000
# 29   >50K    Priv-house-serv       0.000

# %%
# Your Code is Here
#Based on the plotting we get here, we can say that there is a strong relationship between salary and job you are doing. For example,
#if you are working as a Exec-managerial probability of getting more than 50K is higher than any job in the list. It is important
#to note that the people who work as Exec-managerial have two important common characteristics: Firstly, they have the highest rate of
#earning more than 50K. Secondly, they are the most educated people in the dataset.


fig,ax=plt.subplots(figsize=(12,8))
ax=sns.barplot(x=q["salary"],y=round(q["percentage"],2), hue=q["occupation"])
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.0002, p.get_height()+0.002))


plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7brj34F/68.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** We can conclude that as your education level increases the probability of getting a job earning more than 50K also increases.

# %% [markdown]
# ## race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.sample()
# Out:
#        age workclass  fnlwgt education  education_num marital_status  \
# 20506   49   Private  170165   HS-grad          9.000       Divorced
#
#               occupation    relationship   race     sex  capital_gain  \
# 20506  Machine-op-inspct  Other-relative  White  Female             0
#
#        capital_loss  hours_per_week native_country salary
# 20506             0              55  United-States  <=50K

# %%
# Your Code is Here
df.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %% [raw]
# Desired Output:
#
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df.race);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/LdKct3G/69.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("race")["salary"].value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["race"], hue=df["salary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Qb4n8Y5/70.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
# Your Code is Here
df.groupby("race")["salary"].value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %% [raw]
# Desired Output:
#
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xsJWXp4/71.png)

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["race"].value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# Your Code is Here
sns.countplot(x=df["salary"], hue=df["race"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/RBpPR38/72.png)

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby("salary")["race"].value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
a = df.groupby("salary")["race"].value_counts(normalize=True)
b = pd.DataFrame(a)
t=b.rename(columns={"salary":"salary","race":"race","race":"percentage"})
p=t.reset_index()
p
# Out:
#   salary                race  percentage
# 0  <=50K               White       0.837
# 1  <=50K               Black       0.111
# 2  <=50K  Asian-Pac-Islander       0.031
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 4  <=50K               Other       0.010
# 5   >50K               White       0.908
# 6   >50K               Black       0.049
# 7   >50K  Asian-Pac-Islander       0.035
# 8   >50K  Amer-Indian-Eskimo       0.005
# 9   >50K               Other       0.003

# %%
# Your Code is Here

p.sort_values(by=["salary","race"])
# Out:
#   salary                race  percentage
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 2  <=50K  Asian-Pac-Islander       0.031
# 1  <=50K               Black       0.111
# 4  <=50K               Other       0.010
# 0  <=50K               White       0.837
# 8   >50K  Amer-Indian-Eskimo       0.005
# 7   >50K  Asian-Pac-Islander       0.035
# 6   >50K               Black       0.049
# 9   >50K               Other       0.003
# 5   >50K               White       0.908

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Xy9sYCY/73.png)

# %%
# Your Code is Here

sns.barplot(x=p["salary"], y=p["percentage"], hue=p["race"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/X8kf9NZ/74.png)

# %%
#most educated race is white
df.groupby("education")["race"].value_counts(normalize=True).head(60) * 100
# Out:
# education   race
# 10th        White                81.672
#             Black                14.255
#             Amer-Indian-Eskimo    1.715
#             Asian-Pac-Islander    1.393
#             Other                 0.965
# 11th        White                83.149
#             Black                13.021
#             Asian-Pac-Islander    1.787
#             Amer-Indian-Eskimo    1.191
#             Other                 0.851
# 12th        White                77.367
#             Black                16.166
#             Other                 3.233
#             Asian-Pac-Islander    2.079
#             Amer-Indian-Eskimo    1.155
# 1st-4th     White                79.518
#             Black                 9.639
#             Other                 5.422
#             Asian-Pac-Islander    3.012
#             Amer-Indian-Eskimo    2.410
# 5th-6th     White                83.735
#             Black                 6.325
#             Asian-Pac-Islander    5.422
#             Other                 3.916
#             Amer-Indian-Eskimo    0.602
# 7th-8th     White                85.581
#             Black                 8.682
#             Other                 2.636
#             Asian-Pac-Islander    1.705
#             Amer-Indian-Eskimo    1.395
# 9th         White                78.405
#             Black                17.315
#             Asian-Pac-Islander    1.751
#             Other                 1.556
#             Amer-Indian-Eskimo    0.973
# Assoc-acdm  White                85.754
#             Black                10.028
#             Asian-Pac-Islander    2.718
#             Amer-Indian-Eskimo    0.750
#             Other                 0.750
# Assoc-voc   White                87.337
#             Black                 8.104
#             Asian-Pac-Islander    2.750
#             Amer-Indian-Eskimo    1.375
#             Other                 0.434
# Bachelors   White                87.428
#             Black                 6.165
#             Asian-Pac-Islander    5.399
#             Other                 0.616
#             Amer-Indian-Eskimo    0.392
# Doctorate   White                89.346
#             Asian-Pac-Islander    6.780
#             Black                 2.663
#             Amer-Indian-Eskimo    0.726
#             Other                 0.484
# HS-grad     White                84.791
#             Black                11.178
#             Asian-Pac-Islander    2.154
#             Amer-Indian-Eskimo    1.134
#             Other                 0.743
# Name: race, dtype: float64

# %%
#If you are a member of Asian-Pac-Islander you have a higher chance to earn more than 50K compared to other races.
df.groupby("race")["salary"].value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
df.groupby("salary")["race"].value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
#CALCULATION OF E
df[df["race"] == "White"]["education"].value_counts(normalize=True) * 100
# Out:
# HS-grad        32.013
# Some-college   22.306
# Bachelors      16.838
# Masters         5.526
# Assoc-voc       4.343
# 11th            3.515
# Assoc-acdm      3.292
# 10th            2.742
# 7th-8th         1.986
# Prof-school     1.849
# 9th             1.450
# Doctorate       1.328
# 12th            1.205
# 5th-6th         1.000
# 1st-4th         0.475
# Preschool       0.133
# Name: education, dtype: float64

# %%
#CALCULATION OF Z
df[df["race"] == "Asian-Pac-Islander"]["education"].value_counts(normalize=True) * 100
# Out:
# Bachelors      27.842
# HS-grad        21.773
# Some-college   19.942
# Masters         8.478
# Prof-school     3.950
# Assoc-voc       3.661
# Assoc-acdm      2.794
# Doctorate       2.697
# 11th            2.023
# 5th-6th         1.734
# 10th            1.252
# 7th-8th         1.060
# 9th             0.867
# 12th            0.867
# Preschool       0.578
# 1st-4th         0.482
# Name: education, dtype: float64

# %%
#When we have a look at the analyzes above which are called "Z" and "E" we see that the most educated class among races
#is the class of Asian-Pac-Islander. In addition to this, this class of race has the maximum of chance in terms of getting more
#than 50K salary. Do you think why? I think the most important parameter here is the concept of education. So there is a strong
#relationship between salary and education.

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**

# %% [markdown]
# ## gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
# Your Code is Here
df["sex"].value_counts()
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %% [raw]
# Desired Output:
#
# Male      21775
# Female    10762
# Name: gender, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["sex"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/GVTRbrb/75.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("sex")["salary"].value_counts()
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# gender  salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["sex"], hue=df["salary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Nr8HRPk/76.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
# Your Code is Here

a=df.groupby("sex")["salary"].value_counts(normalize=True)
b=pd.DataFrame(a) * 100

b.rename(columns={"sex":"sex","salary":"salary","salary":"percentage" }, inplace=True)
t=b.reset_index()
t
# Out:
#       sex salary  percentage
# 0  Female  <=50K      89.045
# 1  Female   >50K      10.955
# 2    Male  <=50K      69.414
# 3    Male   >50K      30.586

# %% [raw]
# Desired Output:
#
# gender  salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
a=t.loc[[2,3], ["salary"]]["salary"]
z=a.values
z
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
t.loc[[0,1],["salary"]]["salary"].values
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
y
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13       Without-pay  <=50K       1.000
# 14           unknown  <=50K       0.896
# 15           unknown   >50K       0.104

# %%
z
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
plt.pie(t.loc[[0,1], ["percentage"]]["percentage"].values, labels=t.loc[[0,1],["salary"]].values, labeldistance=0.7, autopct="%.2f");

# %%
t
# Out:
#       sex salary  percentage
# 0  Female  <=50K      89.045
# 1  Female   >50K      10.955
# 2    Male  <=50K      69.414
# 3    Male   >50K      30.586

# %%
t.loc[[0,1],["salary"]].values
# Out:
# array([['<=50K'],
#        ['>50K']], dtype=object)

# %%
y
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13       Without-pay  <=50K       1.000
# 14           unknown  <=50K       0.896
# 15           unknown   >50K       0.104

# %%
t
# Out:
#       sex salary  percentage
# 0  Female  <=50K      89.045
# 1  Female   >50K      10.955
# 2    Male  <=50K      69.414
# 3    Male   >50K      30.586

# %%
t.loc[[0,1],["percentage"]].values
# Out:
# array([[89.04478721],
#        [10.95521279]])

# %%
t.loc[[0,1],["percentage"]].values

# %%
t.loc[[0,1]]["percentage"].values

# %%
y["percentage"].values
# Out:
# array([0.61354167, 0.38645833, 0.70520784, 0.29479216, 1.        ,
#        0.78119349, 0.21880651, 0.55734767, 0.44265233, 0.71496063,
#        0.28503937, 0.72804314, 0.27195686, 1.        , 0.8959695 ,
#        0.1040305 ])

# %%
z
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
plt.subplot(1,2,1)
plt.pie(t.loc[[0,1]]["percentage"].values, labels=t.loc[[0,1],["salary"]].values, labeldistance=0.7, autopct="%.2f");
plt.title("Female")

plt.subplot(1,2,2)
plt.pie(y["percentage"].values, labels=z,  labeldistance=0.7, autopct="%.2f")
plt.title("Male")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [281], in <cell line: 6>()
#       3 plt.title("Female")
#       5 plt.subplot(1,2,2)
# ----> 6 plt.pie(y["percentage"].values, labels=z,  labeldistance=0.7, autopct="%.2f")
#       7 plt.title("Male")
#       9 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
#    2745         x, explode=explode, labels=labels, colors=colors,
#    2746         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2747         labeldistance=labeldistance, startangle=startangle,
#    2748         radius=radius, counterclock=counterclock,
#    2749         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2750         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2751         **({"data": data} if data is not None else {}))
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3060, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3058     explode = [0] * len(x)
#    3059 if len(x) != len(labels):
# -> 3060     raise ValueError("'label' must be of length 'x'")
#    3061 if len(x) != len(explode):
#    3062     raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'

# %%
my_colors=["lightpurple", "blue"]

# %%
# Your Code is Here
plt.subplot(1,2,1)
plt.pie(t.loc[[0,1], ["percentage"]]["percentage"].values, labels=t.loc[[0,1],["salary"]].values, labeldistance=0.7, autopct="%.2f");
plt.title("Female")

plt.subplot(1,2,2)
plt.pie(y, labels=z,  labeldistance=0.7, autopct="%.2f")
plt.title("Male")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [249], in <cell line: 7>()
#       4 plt.title("Female")
#       6 plt.subplot(1,2,2)
# ----> 7 plt.pie(y, labels=z,  labeldistance=0.7, autopct="%.2f")
#       8 plt.title("Male")
#      10 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
#    2745         x, explode=explode, labels=labels, colors=colors,
#    2746         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2747         labeldistance=labeldistance, startangle=startangle,
#    2748         radius=radius, counterclock=counterclock,
#    2749         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2750         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2751         **({"data": data} if data is not None else {}))
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3042, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3039 self.set_aspect('equal')
#    3040 # The use of float32 is "historical", but can't be changed without
#    3041 # regenerating the test baselines.
# -> 3042 x = np.asarray(x, np.float32)
#    3043 if x.ndim > 1:
#    3044     raise ValueError("x must be 1D")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2064, in NDFrame.__array__(self, dtype)
#    2063 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'Federal-gov'

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/nrHj2jk/77.png)

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["sex"].value_counts()
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: gender, dtype: int64

# %%
# Your Code is Here
sns.countplot(x=df["salary"], hue=df["sex"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9sfsw11/78.png)

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
# Your Code is Here
df.groupby("salary")["sex"].value_counts(normalize=True)[2:4]
# Out:
# salary  sex
# >50K    Male     0.850
#         Female   0.150
# Name: sex, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: gender, dtype: float64

# %%
a = df.groupby("salary")["sex"].value_counts(normalize=True) * 100
k=a.values
l = a.index
l[2:4]
# Out:
# MultiIndex([('>50K',   'Male'),
#             ('>50K', 'Female')],
#            names=['salary', 'sex'])

# %%
k
# Out:
# array([61.19928739, 38.80071261, 84.9598163 , 15.0401837 ])

# %%
l[[0,1]]
# Out:
# MultiIndex([('<=50K',   'Male'),
#             ('<=50K', 'Female')],
#            names=['salary', 'sex'])

# %%
# Your Code is Here
plt.subplot(1,2,1)
plt.pie(df.groupby("salary")["sex"].value_counts(normalize=True)[0:2],labels=l[[0,1]], labeldistance=0.7, autopct="%.1f", center=(0,8))

plt.subplot(1,2,2)
plt.pie(df.groupby("salary")["sex"].value_counts(normalize=True)[2:4],labels=l[[2,3]], labeldistance=0.7, autopct="%.2f")

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0DzhNgG/79.png)

# %%
#CALCULATION OF K
sns.countplot(x=df["salary"], hue=df["sex"]);

# %%
#CALCULATION OF Q
df.groupby("salary")["sex"].value_counts(normalize=True)
# Out:
# salary  sex
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: sex, dtype: float64

# %%
#CALCULATION OF P
df.groupby("sex")["salary"].value_counts(normalize=True)
# Out:
# sex     salary
# Female  <=50K    0.891
#         >50K     0.109
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** As it can be seen from the calculations of K,Q and P there is an equality between men and women in terms of salary.
# This enquality in salary is in favor of men.

# %% [markdown]
# ## native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df.sample()
# Out:
#        age workclass  fnlwgt  education  education_num marital_status  \
# 20469   30   Private  390879  Assoc-voc         11.000       Divorced
#
#            occupation relationship   race     sex  capital_gain  capital_loss  \
# 20469  Prof-specialty    Unmarried  White  Female             0             0
#
#        hours_per_week native_country salary
# 20469              36  United-States  <=50K

# %%
# Your Code is Here

df.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64

# %% [raw]
# Desired Output:
#
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(16,8))
sns.countplot(x=df["native_country"])
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x3TNT7B/80.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

df["native_country"].replace(to_replace="?", value="unknown", inplace=True)

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
df
# Out:
#        age         workclass  fnlwgt           education  education_num  \
# 0       39         State-gov   77516    high_level_grade         13.000
# 1       50  Self-emp-not-inc   83311    high_level_grade         13.000
# 2       38           Private  215646  medium_level_grade          9.000
# 3       53           Private  234721     low_level_grade          7.000
# 4       28           Private  338409    high_level_grade         13.000
# ...    ...               ...     ...                 ...            ...
# 32556   27           Private  257302  medium_level_grade         12.000
# 32557   40           Private  154374  medium_level_grade          9.000
# 32558   58           Private  151910  medium_level_grade          9.000
# 32559   22           Private  201490  medium_level_grade          9.000
# 32560   52      Self-emp-inc  287927  medium_level_grade          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical        unknown  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
#         education_summary marital_status_summary
# 0        high_level_grade              unmarried
# 1        high_level_grade                married
# 2      medium_level_grade              unmarried
# 3         low_level_grade                married
# 4        high_level_grade                married
# ...                   ...                    ...
# 32556  medium_level_grade                married
# 32557  medium_level_grade                married
# 32558  medium_level_grade              unmarried
# 32559  medium_level_grade              unmarried
# 32560  medium_level_grade                married
#
# [32537 rows x 17 columns]

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"

# Your Code is Here

df["native_country_summary"] = df["native_country"].apply(mapping_native_country)

# %%
df["native_country"] = df3["native_country"]

# %%
df
# Out:
#        age         workclass  fnlwgt           education  education_num  \
# 0       39         State-gov   77516    high_level_grade         13.000
# 1       50  Self-emp-not-inc   83311    high_level_grade         13.000
# 2       38           Private  215646  medium_level_grade          9.000
# 3       53           Private  234721     low_level_grade          7.000
# 4       28           Private  338409    high_level_grade         13.000
# ...    ...               ...     ...                 ...            ...
# 32556   27           Private  257302  medium_level_grade         12.000
# 32557   40           Private  154374  medium_level_grade          9.000
# 32558   58           Private  151910  medium_level_grade          9.000
# 32559   22           Private  201490  medium_level_grade          9.000
# 32560   52      Self-emp-inc  287927  medium_level_grade          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical        unknown  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
#         education_summary marital_status_summary native_country_summary
# 0        high_level_grade              unmarried                     US
# 1        high_level_grade                married                     US
# 2      medium_level_grade              unmarried                     US
# 3         low_level_grade                married                     US
# 4        high_level_grade                married                 Others
# ...                   ...                    ...                    ...
# 32556  medium_level_grade                married                     US
# 32557  medium_level_grade                married                     US
# 32558  medium_level_grade              unmarried                     US
# 32559  medium_level_grade              unmarried                     US
# 32560  medium_level_grade                married                     US
#
# [32537 rows x 18 columns]

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
# Your Code is Here

df["native_country_summary"].value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country_summary, dtype: int64

# %% [raw]
# Desired Output:
#
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
# Your Code is Here

sns.countplot(x=df["native_country_summary"])
plt.xlabel("native_country_summary");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/wwDhVGd/81.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("native_country_summary")["salary"].value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %% [raw]
# Desired Output:
#
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["native_country_summary"], hue=df["salary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/SVnKp4k/82.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("native_country_summary")["salary"].value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %% [raw]
# Desired Output:
#
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4NQ5b1b/83.png)

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["native_country_summary"].value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x=df["salary"], hue=df["native_country_summary"]);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/c1gQfcg/84.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("salary")["native_country_summary"].value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
df.groupby("native_country_summary")["salary"].value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/QHc8m0x/85.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** It is clear that US citizenship or being US-originated has a very important impact on salary. Most people earning more than 50K are US-originated. Based on this fact, we can say that there is a strong relationship between origin and salary.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
# Your Code is Here

df.groupby(["salary","sex"])["age"].mean()
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
df.groupby(["salary","sex"])["age"].mean()
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/BBDy081/86.png)

# %%
# Your Code is Here
#a=df.groupby(["salary","sex"])["age"].mean()
#b = pd.DataFrame(a)
b.rename(columns={"salary":"salary", "sex":"gender", "age":"age"}, inplace=True)
c=b.reset_index()
c.rename(columns={"sex":"gender"}, inplace=True)
c
# Out:
#   salary  gender    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
round(c["age"])
# Out:
# 0   36.000
# 1   37.000
# 2   42.000
# 3   45.000
# Name: age, dtype: float64

# %% [markdown]
# Desired Output:
#
#
# ![image.png](https://i.ibb.co/4PD1208/87.png)

# %%
fig,ax=plt.subplots()
ax=sns.barplot(x=c["salary"], y=round(c["age"],2), hue=c["gender"])




for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.2,p.get_height()))

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2n0yGt7/88.png)

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
# Your Code is Here
df[df["salary"] == ">50K"]["workclass"].value_counts(normalize=True) * 100
# Out:
# Private            63.286
# Self-emp-not-inc    9.236
# Self-emp-inc        7.935
# Local-gov           7.871
# Federal-gov         4.733
# State-gov           4.503
# unknown             2.437
# Name: workclass, dtype: float64

# %% [raw]
# Desired Output:
#
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
round((df[df["salary"] == ">50K"]["workclass"].value_counts(normalize=True) * 100)).values
# Out:
# array([63.,  9.,  8.,  8.,  5.,  5.,  2.])

# %%
fig,ax= plt.subplots()


ax=sns.barplot(x=(df[df["salary"] == ">50K"]["workclass"].value_counts(normalize=True) * 100).index, y=round((df[df["salary"] == ">50K"]["workclass"].value_counts(normalize=True) * 100),2).values)


for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x(),p.get_height()))

# %%
round(13994.4894535893)
# Out:
# 13994

# %%
# Your Code is Here

fig,ax= plt.subplots()


ax=sns.barplot(x=(df[df["salary"] == ">50K"]["workclass"].value_counts(normalize=True) * 100).index, y=round((df[df["salary"] == ">50K"]["workclass"].value_counts(normalize=True) * 100),2).values)

plt.xticks(rotation=65)

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.26,p.get_height()))

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/gMHzLgH/89.png)

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
df.sample(2)
# Out:
#        age workclass  fnlwgt           education  education_num  \
# 22550   44   Private  171722  medium_level_grade          9.000
# 10169   20   Private  234880  medium_level_grade         10.000
#
#       marital_status     occupation relationship   race     sex  capital_gain  \
# 22550      Separated  Other-service    Unmarried  White  Female             0
# 10169  Never-married          Sales      unknown  White  Female             0
#
#        capital_loss  hours_per_week native_country salary   education_summary  \
# 22550             0              39  United-States  <=50K  medium_level_grade
# 10169             0              30  United-States  <=50K  medium_level_grade
#
#       marital_status_summary native_country_summary
# 22550              unmarried                     US
# 10169              unmarried                     US

# %%
# Your Code is Here

df[(df["native_country"] == "United-States") & (df["workclass"] == "Private") & (df["salary"] == ">50K")]["occupation"].value_counts(normalize=True)*100
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %% [raw]
# Desired Output:
#
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
(df5[(df5["native-country"] == "United-States") & (df5["workclass"] == "Private") & (df5["salary"] == ">50K")]["occupation"].value_counts(normalize=True)*100).index
# Out:
# Index(['Exec-managerial', 'Prof-specialty', 'Craft-repair', 'Sales',
#        'Adm-clerical', 'Transport-moving', 'Machine-op-inspct', 'Tech-support',
#        'Other-service', 'Handlers-cleaners', 'Farming-fishing',
#        'Protective-serv', 'Priv-house-serv'],
#       dtype='object')

# %%
round(df5[(df5["native-country"] == "United-States") & (df5["workclass"] == "Private") & (df5["salary"] == ">50K")]["occupation"].value_counts(normalize=True)*100,2).values
# Out:
# array([2.643e+01, 1.949e+01, 1.469e+01, 1.447e+01, 6.390e+00, 5.440e+00,
#        4.450e+00, 4.430e+00, 1.670e+00, 1.340e+00, 5.900e-01, 5.900e-01,
#        2.000e-02])

# %%
a.values
# Out:
# array([2.64375413e+01, 1.94756554e+01, 1.46948667e+01, 1.44745539e+01,
#        6.38907248e+00, 5.44172725e+00, 4.42828817e+00, 4.42828817e+00,
#        1.67437762e+00, 1.34390835e+00, 5.94844679e-01, 5.94844679e-01,
#        2.20312844e-02])

# %%
# Your Code is Here

fig,ax=plt.subplots(figsize=(12,8))
                  
ax=sns.barplot(x=(df5[(df5["native-country"] == "United-States") & (df5["workclass"] == "Private") & (df5["salary"] == ">50K")]["occupation"].value_counts(normalize=True)*100).index, y=round(df5[(df5["native-country"] == "United-States") & (df5["workclass"] == "Private") & (df5["salary"] == ">50K")]["occupation"].value_counts(normalize=True)*100,2).values)
plt.xticks(rotation=90)


for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.26,p.get_height()))

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/s3Kd7VS/90.png)

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
plt.figure(figsize=(12,8))
                  
sns.barplot(x=a.index, y=a.values)
plt.xticks(rotation=90);

# %%
df["race"].value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
df5[(df5["race"] == "Asian-Pac-Islander") & (df5["salary"] == ">50K")]["education"].value_counts(normalize=True) * 100
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
df5 = pd.read_csv("adult_eda.csv")
df5
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %%
# Your Code is Here

df5[(df5["race"] == "Asian-Pac-Islander") & (df5["salary"] == ">50K")]["education"].value_counts(normalize=True) * 100
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %% [raw]
# Desired Output:
#
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
round(df5[(df5["race"] == "Asian-Pac-Islander") & (df5["salary"] == ">50K")]["education"].value_counts(normalize=True) * 100,1).values
# Out:
# array([35.1, 15.6, 12.3, 12. ,  9.8,  6.5,  3.3,  2.9,  1.1,  0.4,  0.4,
#         0.4,  0.4])

# %%
# Your Code is Here

fig, ax= plt.subplots()

ax = sns.barplot(x=df5[(df5["race"] == "Asian-Pac-Islander") & (df5["salary"] == ">50K")]["education"].value_counts(normalize=True).index, y=round(df5[(df5["race"] == "Asian-Pac-Islander") & (df5["salary"] == ">50K")]["education"].value_counts(normalize=True) * 100,2).values)


plt.xticks(rotation=90)

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.15,p.get_height()))

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/rZnSFBX/91.png)

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
df5["race"].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
df5[(df5["race"] =="Asian-Pac-Islander") & (df5["salary"] == ">50K") & (df5["education"] =="Bachelors")]["occupation"].value_counts(normalize=True) * 100
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
df5[(df5["race"] =="Asian-Pac-Islander") & (df5["salary"] == ">50K") & (df5["education"] =="Bachelors")]["occupation"].value_counts(normalize=True)
# Out:
# Exec-managerial     0.278
# Prof-specialty      0.258
# Adm-clerical        0.124
# Sales               0.093
# Other-service       0.093
# Craft-repair        0.072
# Tech-support        0.031
# Protective-serv     0.021
# Transport-moving    0.010
# Machine-op-inspct   0.010
# Farming-fishing     0.010
# Name: occupation, dtype: float64

# %%
round(df5[(df5["race"] =="Asian-Pac-Islander") & (df5["salary"] == ">50K") & (df5["education"] =="Bachelors")]["occupation"].value_counts(normalize=True),2).values
# Out:
# array([0.28, 0.26, 0.12, 0.09, 0.09, 0.07, 0.03, 0.02, 0.01, 0.01, 0.01])

# %%
# Your Code is Here

df5[(df5["race"] =="Asian-Pac-Islander") & (df5["salary"] == ">50K") & (df5["education"] =="Bachelors")]["occupation"].value_counts(normalize=True) * 100
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %% [raw]
# Desired Output:
#
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
# Your Code is Here

fig,ax= plt.subplots()

ax=sns.barplot(x=df5[(df5["race"] =="Asian-Pac-Islander") & (df5["salary"] == ">50K") & (df5["education"] =="Bachelors")]["occupation"].value_counts(normalize=True).index, y=round(df5[(df5["race"] =="Asian-Pac-Islander") & (df5["salary"] == ">50K") & (df5["education"] =="Bachelors")]["occupation"].value_counts(normalize=True)*100,2).values)

plt.xticks(rotation=90)

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.26,p.get_height()))

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/zZVsbJf/92.png)

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/G5KY8nf/93.png)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
#  14  salary                  32537 non-null  object
#  15  education_summary       32537 non-null  object
#  16  marital_status_summary  32537 non-null  object
#  17  native_country_summary  32537 non-null  object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 5.7+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
#  14  salary                  32537 non-null  object
#  15  education_summary       32537 non-null  object
#  16  marital_status_summary  32537 non-null  object
#  17  native_country_summary  32537 non-null  object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 5.7+ MB

# %%
df
# Out:
#        age         workclass  fnlwgt           education  education_num  \
# 0       39         State-gov   77516    high_level_grade         13.000
# 1       50  Self-emp-not-inc   83311    high_level_grade         13.000
# 2       38           Private  215646  medium_level_grade          9.000
# 3       53           Private  234721     low_level_grade          7.000
# 4       28           Private  338409    high_level_grade         13.000
# ...    ...               ...     ...                 ...            ...
# 32556   27           Private  257302  medium_level_grade         12.000
# 32557   40           Private  154374  medium_level_grade          9.000
# 32558   58           Private  151910  medium_level_grade          9.000
# 32559   22           Private  201490  medium_level_grade          9.000
# 32560   52      Self-emp-inc  287927  medium_level_grade          9.000
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical        unknown  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
#         education_summary marital_status_summary native_country_summary
# 0        high_level_grade              unmarried                     US
# 1        high_level_grade                married                     US
# 2      medium_level_grade              unmarried                     US
# 3         low_level_grade                married                     US
# 4        high_level_grade                married                 Others
# ...                   ...                    ...                    ...
# 32556  medium_level_grade                married                     US
# 32557  medium_level_grade                married                     US
# 32558  medium_level_grade              unmarried                     US
# 32559  medium_level_grade              unmarried                     US
# 32560  medium_level_grade                married                     US
#
# [32537 rows x 18 columns]

# %%
# Drop the columns of "education", "education_num", "relationship", "marital_status", "native_country" permanently

# Your Code is Here

df.drop([["education", "education_num", "relationship", "marital_status", "native_country"]], axis=1, inplace=True)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
# Your Code is Here

df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
# Your Code is Here

df["workclass"].value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %% [raw]
# Desired Output:
#
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
a=df["workclass"].value_counts()
b=pd.DataFrame(a)
b.loc[["unknown","Never-worked"]]
# Out:
#               workclass
# unknown            1836
# Never-worked          7

# %%
# Your Code is Here

df["occupation"].value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %% [raw]
# Desired Output:
#
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

a=df["workclass"].value_counts()
b=pd.DataFrame(a)
b.loc[["unknown","Never-worked"]]
# Out:
#               workclass
# unknown            1836
# Never-worked          7

# %% [raw]
# Desired Output:
#
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
# Replace "Unknown" values with NaN using numpy library

# Your Code is Here

df["workclass"].value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# NaN                  1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here
df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [raw]
# Desired Output:
#
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# gender                       0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
# Drop missing values in df permanently

# Your Code is Here

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   gender                  30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/DKMSBDk/94.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JKtcs9S/95.png)

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/fMpP3yR/96.png)

# %% [markdown]
# **Check the statistical values for all numeric features**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/t3MJHDr/97.png)

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/SnzH5Nz/98.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (28.0, 47.0, 19.0)

# %%
# Find lower and upper limit using IQR

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (-0.5, 75.5)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x2wDgzQ/99.png)

# %% [markdown]
# ### hours_per_week

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xq53X6w/100.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (40.0, 45.0, 5.0)

# %%
# Find the lower and upper limit using IQR

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (32.5, 52.5)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/zGCnbjz/101.png)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/swYNtdM/102.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/S7RWpxD/103.png)

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Create a condition according to your domain knowledge on age stated above and 
# sort the observations meeting this condition by age in ascending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/pJC50ZV/104.png)

# %%
# Find the shape of the dataframe created by the condition defined above for age 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (76, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for age

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([  222, 18832, 10545, 11512, 11996, 12975, 14159, 15892, 18277,
#             18413, 18725, 19212,  8973, 19489, 19747, 20610, 22220, 24043,
#             28463, 31030, 32277, 32367, 10210, 15356,  5370,  4070,  1040,
#              6232,  1935,  2303,  5272,  6624,  2891,  5406,  8806,  1168,
#             22895, 21835, 24027, 20463,  8381, 32459, 26731, 27795,  9471,
#              6214, 14711, 11238,  7720, 15662,  7481, 24395, 23459, 19172,
#             16302, 14756,  8431, 20421, 22481, 31855, 13696, 24280,  4834,
#             29594, 28948, 12830,   918, 13295, 24560,  3537, 13928, 19045,
#              6748,  2906, 21501, 19495],
#            dtype='int64')

# %%
# Drop these indices defined above for age

# Your Code is Here

# %%
# Create a condition according to your domain knowledge on hours per week stated above and 
# sort the observations meeting this condition by hours per week in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/rMp7C58/105.png)

# %%
# Find the shape of the dataframe created by the condition defined above for hours per week 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (621, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
# Drop these indices defined above for hours per week

# Your Code is Here

# %%
# Create a condition according to your domain knowledge on both age and hours per week stated above 

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Ch8XSdW/106.png)

# %%
# Find the shape of the dataframe created by the condition defined above for both age and hours per week


# Your Code is Here

# %% [raw]
# Desired Output:
#
# (23, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for both age and hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
# Drop these indices defined above for both age and hours per week

# Your Code is Here

# %%
# What is new shape of dataframe now

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# Reset the indices and take the head of DataFrame now

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5MXPD2b/107.png)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29969    0
# 29970    1
# 29971    0
# 29972    0
# 29973    1
# Name: salary, Length: 29974, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0F1SHRt/108.png)

# %%
# What's the shape of dataframe

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# What's the shape of dataframe created by dummy operation

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 34)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Dgb8RYZ/109.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5XH3X4q/110.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/19RytkS/111.png)

# %%
# Your Code is Here

# %% [markdown]
# ![image.png](https://i.ibb.co/80GcYKr/112.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0MCPc4d/113.png)

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
